# %%
configs = {
    "fs.azure.account.auth.type": "CustomAccessToken",
    "fs.azure.account.custome.provider.class": spark.conf.get("spark.databricks.passthrough.adls.gen2.customProviderClassName")
}

dbutils.fs.mount(
  source = "abfss://bronze@intechsc.dfs.core.windows.net/",
  mount_point = "/mnt/bronze/",
  extra_configs = configs)

# %%
dbutils.fs.ls("/mnt/bronze")

# %%
dbutils.fs.mount(
  source = "abfss://silver@intechsc.dfs.core.windows.net/",
  mount_point = "/mnt/silver",
  extra_configs = configs)

dbutils.fs.mount(
  source = "abfss://gold@intechsc.dfs.core.windows.net/",
  mount_point = "/mnt/gold",
  extra_configs = configs)
